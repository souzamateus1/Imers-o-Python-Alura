# %% [markdown]
# <a href="https://colab.research.google.com/github/souzamateus1/Imers-o-Python-Alura/blob/main/Imersao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imersão Phyton

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/acoes.xlsx", sheet_name="Principal")
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5  1/26/2024         9.50          5.20          11.76          2.26
# 1  CMIN3  1/26/2024         6.82          2.40           2.40        -12.11
# 2  PETR3  1/26/2024        41.96          2.19           7.73          7.64
# 3  SUZB3  1/26/2024        52.91          2.04           2.14         -4.89
# 4  CPFE3  1/26/2024        37.10          2.03           2.49         -3.66
# 5  PRIO3  1/26/2024        45.69          1.98           2.42         -0.78
# 6  PETR4  1/26/2024        39.96          1.73           6.47          7.30
# 7  VALE3  1/26/2024        69.50          1.66           2.06         -9.97
# 8  MULT3  1/26/2024        28.19          1.58           2.03         -0.81
# 9  ITUB4  1/26/2024        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ...  Variação $.2  \
# 0          2.26         15.97      9.18      9.56  ...  1.081515e+08
# 1        -12.11         50.56      6.66      6.86  ... -1.043592e+09
# 2          7.64         77.55     40.81     42.34  ...  7.087773e+09
# 3         -4.89         18.85     51.89     53.17  ... -1.859212e+09
# 4         -3.66         20.70     36.37     37.32  ... -2.645988e+08
# 5         -0.78          8.08     44.25     45.69  ... -2.873508e+08
# 6          7.30         95.01     38.91     40.09  ...  1.241443e+10
# 7         -9.97        -23.49     67.50     69.81  ... -3.230159e+10
# 8         -0.81         24.02     27.71     28.36  ... -6.181093e+07
# 9         -3.36         34.25     32.35     32.91  ... -5.477394e+09
#
#    Resultado.2  Variação Ano %  Valor Inicial (R$).3  Variação $.3  \
# 0        Subiu          0.0226                  9.29  1.081515e+08
# 1       Desceu         -0.1211                  7.76 -1.043592e+09
# 2        Subiu          0.0764                 38.98  7.087773e+09
# 3       Desceu         -0.0489                 55.63 -1.859212e+09
# 4       Desceu         -0.0366                 38.51 -2.645988e+08
# 5       Desceu         -0.0078                 46.05 -2.873508e+08
# 6        Subiu          0.0730                 37.24  1.241443e+10
# 7       Desceu         -0.0997                 77.20 -3.230159e+10
# 8       Desceu         -0.0081                 28.42 -6.181093e+07
# 9       Desceu         -0.0336                 33.95 -5.477394e+09
#
#   Resultado.3 Variação 12M % Valor Inicial (R$).4  Variação $.4 Resultado.4
# 0       Subiu         0.1597                 8.19  6.738901e+08       Subiu
# 1      Desceu         0.5056                 4.53  2.543452e+09       Subiu
# 2       Subiu         0.7755                23.63  4.361654e+10       Subiu
# 3      Desceu         0.1885                44.52  5.735331e+09       Subiu
# 4      Desceu         0.2070                30.74  1.194474e+09       Subiu
# 5      Desceu         0.0808                42.27  2.732644e+09       Subiu
# 6       Subiu         0.9501                20.49  8.890296e+10       Subiu
# 7      Desceu        -0.2349                90.84 -8.955313e+10      Desceu
# 8      Desceu         0.2402                22.73  1.465985e+09       Subiu
# 9      Desceu         0.3425                24.44  4.019184e+10       Subiu
#
# [10 rows x 36 columns]

# %%
df_total_de_acoes = pd.read_excel("/content/acoes.xlsx", sheet_name="total_de_acoes")
df_total_de_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/acoes.xlsx", sheet_name="ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_Chatgpt = pd.read_excel("/content/acoes.xlsx", sheet_name="Chatgpt")
df_Chatgpt
# Out:
#      Nome da Empresa           Segmento  Idade (anos)
# 0           Usiminas         Siderurgia            60
# 1      CSN Mineração          Mineração            80
# 2          Petrobras            Energia            68
# 3             Suzano   Papel e Celulose            97
# 4       CPFL Energia            Energia           108
# ..               ...                ...           ...
# 76  Carrefour Brasil             Varejo            46
# 77       Casas Bahia             Varejo            67
# 78          Localiza  Aluguel de Carros            48
# 79               CVC            Turismo            49
# 80               GOL            Aviação            21
#
# [81 rows x 3 columns]

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5  1/26/2024         9.50          5.20
# 1   CMIN3  1/26/2024         6.82          2.40
# 2   PETR3  1/26/2024        41.96          2.19
# 3   SUZB3  1/26/2024        52.91          2.04
# 4   CPFE3  1/26/2024        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3  1/26/2024        10.71         -2.45
# 77  BHIA3  1/26/2024         8.70         -2.46
# 78  RENT3  1/26/2024        56.24         -3.63
# 79  CVCB3  1/26/2024         3.07         -4.36
# 80  GOLL4  1/26/2024         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)': 'Valor_final', 'Var. Dia (%)': 'Var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct
# 0   USIM5  1/26/2024         9.50         5.20
# 1   CMIN3  1/26/2024         6.82         2.40
# 2   PETR3  1/26/2024        41.96         2.19
# 3   SUZB3  1/26/2024        52.91         2.04
# 4   CPFE3  1/26/2024        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3  1/26/2024        10.71        -2.45
# 77  BHIA3  1/26/2024         8.70        -2.46
# 78  RENT3  1/26/2024        56.24        -3.63
# 79  CVCB3  1/26/2024         3.07        -4.36
# 80  GOLL4  1/26/2024         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['Var_dia_pct'] / 100
df_principal['Valor_inicial'] = df_principal['Valor_final'] / (df_principal['Var_pct'] + 1)
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial
# 0   USIM5  1/26/2024         9.50         5.20   0.0520       9.030418
# 1   CMIN3  1/26/2024         6.82         2.40   0.0240       6.660156
# 2   PETR3  1/26/2024        41.96         2.19   0.0219      41.060769
# 3   SUZB3  1/26/2024        52.91         2.04   0.0204      51.852215
# 4   CPFE3  1/26/2024        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3  1/26/2024         8.70        -2.46  -0.0246       8.919418
# 78  RENT3  1/26/2024        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3  1/26/2024         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4  1/26/2024         5.92        -8.07  -0.0807       6.439682
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_total_de_acoes,left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial Código  \
# 0   USIM5  1/26/2024         9.50         5.20   0.0520       9.030418  USIM5
# 1   CMIN3  1/26/2024         6.82         2.40   0.0240       6.660156  CMIN3
# 2   PETR3  1/26/2024        41.96         2.19   0.0219      41.060769  PETR3
# 3   SUZB3  1/26/2024        52.91         2.04   0.0204      51.852215  SUZB3
# 4   CPFE3  1/26/2024        37.10         2.03   0.0203      36.361854  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3  1/26/2024        10.71        -2.45  -0.0245      10.978985  CRFB3
# 77  BHIA3  1/26/2024         8.70        -2.46  -0.0246       8.919418  BHIA3
# 78  RENT3  1/26/2024        56.24        -3.63  -0.0363      58.358410  RENT3
# 79  CVCB3  1/26/2024         3.07        -4.36  -0.0436       3.209954  CVCB3
# 80  GOLL4  1/26/2024         5.92        -8.07  -0.0807       6.439682  GOLL4
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20   0.0520       9.030418
# 1   CMIN3  1/26/2024         6.82         2.40   0.0240       6.660156
# 2   PETR3  1/26/2024        41.96         2.19   0.0219      41.060769
# 3   SUZB3  1/26/2024        52.91         2.04   0.0204      51.852215
# 4   CPFE3  1/26/2024        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3  1/26/2024         8.70        -2.46  -0.0246       8.919418
# 78  RENT3  1/26/2024        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3  1/26/2024         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4  1/26/2024         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 7 columns]

# %%
df_principal['variacao_rs'] = (df_principal['Valor_final'] - df_principal['Valor_inicial'])*df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20   0.0520       9.030418
# 1   CMIN3  1/26/2024         6.82         2.40   0.0240       6.660156
# 2   PETR3  1/26/2024        41.96         2.19   0.0219      41.060769
# 3   SUZB3  1/26/2024        52.91         2.04   0.0204      51.852215
# 4   CPFE3  1/26/2024        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3  1/26/2024         8.70        -2.46  -0.0246       8.919418
# 78  RENT3  1/26/2024        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3  1/26/2024         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4  1/26/2024         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica   variacao_rs
# 0    5.151174e+08  2.418897e+08
# 1    1.110559e+09  1.775160e+08
# 2    2.379878e+09  2.140059e+09
# 3    6.834528e+08  7.229463e+08
# 4    1.877325e+08  1.385740e+08
# ..            ...           ...
# 76   5.339906e+08 -1.436355e+08
# 77   9.484305e+07 -2.081024e+07
# 78   8.532023e+08 -1.807433e+09
# 79   5.255828e+08 -7.355741e+07
# 80   1.981849e+08 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}' .format

# %%
df_principal ['Qtde. Teórica'] = df_principal['Qtde. Teórica'] .astype(int)
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica': 'Qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['variacao_rs'].apply (lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    variacao_rs Resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    variacao_rs Resultado Ticker              Nome
# 0     515117391   241889725.43     Subiu  USIM5          Usiminas
# 1    1110559345   177515970.30     Subiu  CMIN3     CSN Mineração
# 2    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 3     683452836   722946282.71     Subiu  SUZB3            Suzano
# 4     187732538   138573955.06     Subiu  CPFE3      CPFL Energia
# ..          ...            ...       ...    ...               ...
# 76    533990587  -143635530.57    Desceu  CRFB3  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu  BHIA3       Casas Bahia
# 78    853202347 -1807432634.46    Desceu  RENT3          Localiza
# 79    525582771   -73557408.06    Desceu  CVCB3               CVC
# 80    198184909  -102993202.62    Desceu  GOLL4               GOL
#
# [81 rows x 11 columns]

# %%
df_principal = df_principal.merge(df_Chatgpt, left_on='Nome', right_on='Nome da Empresa', how='left')
df_principal = df_principal.drop(columns='Nome da Empresa')
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 4   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 83  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 84  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 85  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 86  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    variacao_rs Resultado Ticker              Nome  \
# 0     515117391   241889725.43     Subiu  USIM5          Usiminas
# 1    1110559345   177515970.30     Subiu  CMIN3     CSN Mineração
# 2    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 3    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 4     683452836   722946282.71     Subiu  SUZB3            Suzano
# ..          ...            ...       ...    ...               ...
# 82    533990587  -143635530.57    Desceu  CRFB3  Carrefour Brasil
# 83     94843047   -20810240.84    Desceu  BHIA3       Casas Bahia
# 84    853202347 -1807432634.46    Desceu  RENT3          Localiza
# 85    525582771   -73557408.06    Desceu  CVCB3               CVC
# 86    198184909  -102993202.62    Desceu  GOLL4               GOL
#
#              Segmento  Idade (anos)
# 0          Siderurgia         60.00
# 1           Mineração         80.00
# 2             Energia         68.00
# 3             Energia         68.00
# 4    Papel e Celulose         97.00
# ..                ...           ...
# 82             Varejo         46.00
# 83             Varejo         67.00
# 84  Aluguel de Carros         48.00
# 85            Turismo         49.00
# 86            Aviação         21.00
#
# [87 rows x 13 columns]

# %%
df_principal['Categoria de idade'] = df_principal['Idade (anos)'].apply (lambda x: 'Mais de 100 anos' if x > 100 else ('Menos de 50 anos' if x < 0 else 'Entre 50 e 100 anos'))
df_principal
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 4   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 83  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 84  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 85  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 86  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    variacao_rs Resultado Ticker              Nome  \
# 0     515117391   241889725.43     Subiu  USIM5          Usiminas
# 1    1110559345   177515970.30     Subiu  CMIN3     CSN Mineração
# 2    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 3    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 4     683452836   722946282.71     Subiu  SUZB3            Suzano
# ..          ...            ...       ...    ...               ...
# 82    533990587  -143635530.57    Desceu  CRFB3  Carrefour Brasil
# 83     94843047   -20810240.84    Desceu  BHIA3       Casas Bahia
# 84    853202347 -1807432634.46    Desceu  RENT3          Localiza
# 85    525582771   -73557408.06    Desceu  CVCB3               CVC
# 86    198184909  -102993202.62    Desceu  GOLL4               GOL
#
#              Segmento  Idade (anos)   Categoria de idade
# 0          Siderurgia         60.00  Entre 50 e 100 anos
# 1           Mineração         80.00  Entre 50 e 100 anos
# 2             Energia         68.00  Entre 50 e 100 anos
# 3             Energia         68.00  Entre 50 e 100 anos
# 4    Papel e Celulose         97.00  Entre 50 e 100 anos
# ..                ...           ...                  ...
# 82             Varejo         46.00  Entre 50 e 100 anos
# 83             Varejo         67.00  Entre 50 e 100 anos
# 84  Aluguel de Carros         48.00  Entre 50 e 100 anos
# 85            Turismo         49.00  Entre 50 e 100 anos
# 86            Aviação         21.00  Entre 50 e 100 anos
#
# [87 rows x 14 columns]

# %%
# Calculando o maior valor
maior = df_principal['variacao_rs'].max()

# Calculando o menor valor
menor = df_principal['variacao_rs'].min()

# Calculando a média geral
media_geral = df_principal['variacao_rs'].mean()

# Calculando a média de quem subiu
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['variacao_rs'].mean()

# Calculando a média de quem desceu
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['variacao_rs'].mean()

# Exibindo os resultados
print("Maior\t", f"R$ {maior:,.2f}")
print("Menor\t", f"R$ {menor:,.2f}")
print("Média\t", f"R$ {media_geral:,.2f}")
print("Média de quem subiu\t", f"R$ {media_subiu:,.2f}")
print("Média de quem desceu\t", f"R$ {media_desceu:,.2f}")
# Out:
# Maior	 R$ 4,762,926,995.25
# Menor	 R$ -1,807,432,634.46
# Média	 R$ 218,008,898.33
# Média de quem subiu	 R$ 538,720,638.36
# Média de quem desceu	 R$ -186,265,310.46

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  Valor_final  Var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 4   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 5   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# 6   PRIO3  1/26/2024        45.69         1.98     0.02          44.80
# 7   PETR4  1/26/2024        39.96         1.73     0.02          39.28
# 8   PETR4  1/26/2024        39.96         1.73     0.02          39.28
# 9   VALE3  1/26/2024        69.50         1.66     0.02          68.37
# 10  MULT3  1/26/2024        28.19         1.58     0.02          27.75
# 11  ITUB4  1/26/2024        32.81         1.48     0.01          32.33
# 12  RDOR3  1/26/2024        27.56         1.43     0.01          27.17
# 13  BRKM5  1/26/2024        18.55         1.42     0.01          18.29
# 14  AZUL4  1/26/2024        14.27         1.42     0.01          14.07
# 15  RRRP3  1/26/2024        28.75         1.41     0.01          28.35
# 16  EQTL3  1/26/2024        35.32         1.34     0.01          34.85
# 17  CSNA3  1/26/2024        18.16         1.33     0.01          17.92
# 18  YDUQ3  1/26/2024        19.77         1.28     0.01          19.52
# 19  UGPA3  1/26/2024        28.31         1.28     0.01          27.95
# 20  MRVE3  1/26/2024         8.08         1.25     0.01           7.98
# 21  ARZZ3  1/26/2024        57.91         1.15     0.01          57.25
# 22  BBDC4  1/26/2024        15.52         1.04     0.01          15.36
# 23  BBDC4  1/26/2024        15.52         1.04     0.01          15.36
# 24  BEEF3  1/26/2024         7.19         0.98     0.01           7.12
# 25  PCAR3  1/26/2024         4.14         0.97     0.01           4.10
# 26  BRFS3  1/26/2024        14.61         0.96     0.01          14.47
# 27  VIVT3  1/26/2024        51.20         0.88     0.01          50.75
# 28  RAIL3  1/26/2024        22.64         0.84     0.01          22.45
# 29  CIEL3  1/26/2024         4.90         0.82     0.01           4.86
# 30  DXCO3  1/26/2024         7.81         0.77     0.01           7.75
# 31  TIMS3  1/26/2024        17.52         0.74     0.01          17.39
# 32  BRAP4  1/26/2024        23.22         0.73     0.01          23.05
# 33  LWSA3  1/26/2024         5.55         0.72     0.01           5.51
# 34  RECV3  1/26/2024        23.83         0.71     0.01          23.66
# 35  ITSA4  1/26/2024        10.01         0.70     0.01           9.94
# 36  BBAS3  1/26/2024        56.97         0.68     0.01          56.59
# 37  RADL3  1/26/2024        26.16         0.61     0.01          26.00
# 38  GOAU4  1/26/2024        10.08         0.59     0.01          10.02
# 39  CSAN3  1/26/2024        18.57         0.59     0.01          18.46
# 40  JBSS3  1/26/2024        24.34         0.57     0.01          24.20
# 41  MGLU3  1/26/2024         2.08         0.48     0.00           2.07
# 42  BBDC3  1/26/2024        13.75         0.36     0.00          13.70
# 43  BBDC3  1/26/2024        13.75         0.36     0.00          13.70
# 44  GGBR4  1/26/2024        21.84         0.27     0.00          21.78
# 45  RAIZ4  1/26/2024         3.74         0.26     0.00           3.73
# 46  CPLE6  1/26/2024        10.07         0.19     0.00          10.05
# 47  VAMO3  1/26/2024         8.18         0.12     0.00           8.17
#
#     Qtd_teorica   variacao_rs Resultado Ticker                  Nome  \
# 0     515117391  241889725.43     Subiu  USIM5              Usiminas
# 1    1110559345  177515970.30     Subiu  CMIN3         CSN Mineração
# 2    2379877655 2140059393.53     Subiu  PETR3             Petrobras
# 3    2379877655 2140059393.53     Subiu  PETR3             Petrobras
# 4     683452836  722946282.71     Subiu  SUZB3                Suzano
# 5     187732538  138573955.06     Subiu  CPFE3          CPFL Energia
# 6     800010734  709687498.18     Subiu  PRIO3              PetroRio
# 7    4566445852 3103136291.22     Subiu  PETR4             Petrobras
# 8    4566445852 3103136291.22     Subiu  PETR4             Petrobras
# 9    4196924316 4762926995.25     Subiu  VALE3                  Vale
# 10    268505432  117732680.08     Subiu  MULT3             Multiplan
# 11   4801593832 2297591984.33     Subiu  ITUB4         Itaú Unibanco
# 12   1168230366  453917907.01     Subiu  RDOR3             Rede D'Or
# 13    265877867   69054317.64     Subiu  BRKM5               Braskem
# 14    327593725   65452205.55     Subiu  AZUL4                  Azul
# 15    235665566   94204643.35     Subiu  RRRP3          3R Petroleum
# 16   1095587251  511671895.45     Subiu  EQTL3    Equatorial Energia
# 17    600865451  143220991.46     Subiu  CSNA3  Siderúrgica Nacional
# 18    289347914   72295838.99     Subiu  YDUQ3                 YDUQS
# 19   1086411192  388705223.96     Subiu  UGPA3              Ultrapar
# 20    376187582   37525872.38     Subiu  MRVE3                   MRV
# 21     62305891   41021792.09     Subiu  ARZZ3                Arezzo
# 22   5146576868  822148336.41     Subiu  BBDC4        Banco Bradesco
# 23   5146576868  822148336.41     Subiu  BBDC4        Banco Bradesco
# 24    261036182   18214628.10     Subiu  BEEF3               Minerva
# 25    159430826    6340916.22     Subiu  PCAR3   Grupo Pão de Açúcar
# 26   1677525446  233045769.57     Subiu  BRFS3                   BRF
# 27    423091712  188965307.06     Subiu  VIVT3                  Vivo
# 28   1218352541  229771333.63     Subiu  RAIL3                  Rumo
# 29   1095462329   43657683.38     Subiu  CIEL3                 Cielo
# 30    302768240   18068446.61     Subiu  DXCO3                 Dexco
# 31    807896814  103972807.37     Subiu  TIMS3                   TIM
# 32    251003438   42238249.54     Subiu  BRAP4             Bradespar
# 33    393173139   15598886.65     Subiu  LWSA3               Locaweb
# 34    275005663   46201006.00     Subiu  RECV3        PetroRecôncavo
# 35   5372783971  373853994.88     Subiu  ITSA4                Itaúsa
# 36   1420949112  546752087.99     Subiu  BBAS3       Banco do Brasil
# 37   1275798515  202352473.74     Subiu  RADL3          RaiaDrogasil
# 38    660411219   39045606.94     Subiu  GOAU4    Metalúrgica Gerdau
# 39   1168097881  127229653.18     Subiu  CSAN3                 Cosan
# 40   1134986472  156573285.43     Subiu  JBSS3                   JBS
# 41   2867627068   28493619.27     Subiu  MGLU3        Magazine Luiza
# 42   1500728902   74019610.05     Subiu  BBDC3        Banco Bradesco
# 43   1500728902   74019610.05     Subiu  BBDC3        Banco Bradesco
# 44   1118525506   65779607.10     Subiu  GGBR4                Gerdau
# 45   1193047233   11571106.42     Subiu  RAIZ4                Raízen
# 46   1679335290   32069789.50     Subiu  CPLE6                 Copel
# 47    421383330    4131341.16     Subiu  VAMO3           Grupo Vamos
#
#                 Segmento  Idade (anos)   Categoria de idade
# 0             Siderurgia         60.00  Entre 50 e 100 anos
# 1              Mineração         80.00  Entre 50 e 100 anos
# 2                Energia         68.00  Entre 50 e 100 anos
# 3                Energia         68.00  Entre 50 e 100 anos
# 4       Papel e Celulose         97.00  Entre 50 e 100 anos
# 5                Energia        108.00     Mais de 100 anos
# 6         Petróleo e Gás         10.00  Entre 50 e 100 anos
# 7                Energia         68.00  Entre 50 e 100 anos
# 8                Energia         68.00  Entre 50 e 100 anos
# 9              Mineração         80.00  Entre 50 e 100 anos
# 10      Shopping Centers         48.00  Entre 50 e 100 anos
# 11  Serviços Financeiros         98.00  Entre 50 e 100 anos
# 12                   NaN           NaN  Entre 50 e 100 anos
# 13               Química         20.00  Entre 50 e 100 anos
# 14      Transporte Aéreo         13.00  Entre 50 e 100 anos
# 15        Petróleo e Gás          3.00  Entre 50 e 100 anos
# 16      Energia Elétrica         23.00  Entre 50 e 100 anos
# 17            Siderurgia         79.00  Entre 50 e 100 anos
# 18              Educação         53.00  Entre 50 e 100 anos
# 19          Combustíveis         84.00  Entre 50 e 100 anos
# 20            Construção         42.00  Entre 50 e 100 anos
# 21                Varejo         50.00  Entre 50 e 100 anos
# 22  Serviços Financeiros         78.00  Entre 50 e 100 anos
# 23  Serviços Financeiros         78.00  Entre 50 e 100 anos
# 24             Alimentos         29.00  Entre 50 e 100 anos
# 25                Varejo         72.00  Entre 50 e 100 anos
# 26             Alimentos         84.00  Entre 50 e 100 anos
# 27      Telecomunicações         22.00  Entre 50 e 100 anos
# 28             Logística          6.00  Entre 50 e 100 anos
# 29    Meios de Pagamento         24.00  Entre 50 e 100 anos
# 30         Investimentos          1.00  Entre 50 e 100 anos
# 31      Telecomunicações         25.00  Entre 50 e 100 anos
# 32         Investimentos         20.00  Entre 50 e 100 anos
# 33            Tecnologia         24.00  Entre 50 e 100 anos
# 34        Petróleo e Gás          5.00  Entre 50 e 100 anos
# 35         Investimentos         56.00  Entre 50 e 100 anos
# 36  Serviços Financeiros        213.00     Mais de 100 anos
# 37             Farmácias         25.00  Entre 50 e 100 anos
# 38            Siderurgia        120.00     Mais de 100 anos
# 39               Energia         24.00  Entre 50 e 100 anos
# 40             Alimentos         68.00  Entre 50 e 100 anos
# 41                Varejo         64.00  Entre 50 e 100 anos
# 42  Serviços Financeiros         78.00  Entre 50 e 100 anos
# 43  Serviços Financeiros         78.00  Entre 50 e 100 anos
# 44            Siderurgia        120.00     Mais de 100 anos
# 45               Energia         10.00  Entre 50 e 100 anos
# 46               Energia         67.00  Entre 50 e 100 anos
# 47             Logística          5.00  Entre 50 e 100 anos

# %%
df_analise_Segmento = df_principal_subiu.groupby('Segmento')['variacao_rs'].sum().reset_index()
df_analise_Segmento
# Out:
#                 Segmento    variacao_rs
# 0              Alimentos   407833683.09
# 1           Combustíveis   388705223.96
# 2             Construção    37525872.38
# 3               Educação    72295838.99
# 4                Energia 10795835873.64
# 5       Energia Elétrica   511671895.45
# 6              Farmácias   202352473.74
# 7          Investimentos   434160691.03
# 8              Logística   233902674.79
# 9     Meios de Pagamento    43657683.38
# 10             Mineração  4940442965.55
# 11      Papel e Celulose   722946282.71
# 12        Petróleo e Gás   850093147.52
# 13               Química    69054317.64
# 14  Serviços Financeiros  4636679965.25
# 15      Shopping Centers   117732680.08
# 16            Siderurgia   489935930.93
# 17            Tecnologia    15598886.65
# 18      Telecomunicações   292938114.42
# 19      Transporte Aéreo    65452205.55
# 20                Varejo    75856327.59

# %%
df_analise_saldo = df_principal.groupby('Resultado')['variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    variacao_rs
# 0    Desceu -6891816486.99
# 1   Estável           0.00
# 2     Subiu 25858590641.35

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='variacao_rs', text='variacao_rs', title='Variação reais por Resultado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1882add5-67df-4748-ad09-911f0e037b90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1882add5-67df-4748-ad09-911f0e037b90")) {                    Plotly.newPlot(                        "1882add5-67df-4748-ad09-911f0e037b90",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003evariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6891816486.985515,0.0,25858590641.34758],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6891816486.985515,0.0,25858590641.34758],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar" ...

# %%
import plotly.express as px
fig = px.pie(df_analise_Segmento, values='variacao_rs', names='Segmento', title='Variação reais por Segmento')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0285e6a1-05d6-477e-980e-799e0e36c1ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0285e6a1-05d6-477e-980e-799e0e36c1ab")) {                    Plotly.newPlot(                        "0285e6a1-05d6-477e-980e-799e0e36c1ab",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segmento=%{label}\u003cbr\u003evariacao_rs=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Alimentos","Combust\u00edveis","Constru\u00e7\u00e3o","Educa\u00e7\u00e3o","Energia","Energia El\u00e9trica","Farm\u00e1cias","Investimentos","Log\u00edstica","Meios de Pagamento","Minera\u00e7\u00e3o","Papel e Celulose","Petr\u00f3leo e G\u00e1s","Qu\u00edmica","Servi\u00e7os Financeiros","Shopping Centers","Siderurgia","Tecnologia","Telecomunica\u00e7\u00f5es","Transporte A\u00e9reo","Varejo"],"legendgroup":"","name":"","showlegend":true,"values":[407833683.0924499,388705223.95601785,37525872.37728388,72295838.98616095,10795835873.641844,511671895.45223427,202352473.73982856,434160691.03374624,233902674.79257408,43657683.37554085,4940442965.550434,722946282.7090385,850093147.5214361,69054317.63603853,4636679965.247721,117732680.0784251,489935930.9283229,15598886.650556229,292938114.42357796,65452205.552800186,75856327.58830959],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdc ...
